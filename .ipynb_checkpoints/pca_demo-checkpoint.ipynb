# %% [markdown]
# 主成分分析

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.empty([100,2])
x[:,0] = np.random.uniform(0.,100.,size = 100)
x[:,1] = 0.75 * x[:,0] + 3. + np.random.normal(0,10.,size = 100)
plt.scatter(x[:,0],x[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# demean操作

# %%
def demean(x):
    return x - np.mean(x,axis = 0)

# %%
x_demean = demean(x)
plt.scatter(x_demean[:,0],x_demean[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
np.mean(x_demean[:,0])
# Out:
# -5.897504706808831e-15

# %%
np.mean(x_demean[:,1])
# Out:
# -2.2026824808563106e-15

# %%
#pca 效用函数
def f(w,x):
    return np.sum((x.dot(w) ** 2)) / len(x)

def df_math(w,x):
    return x.T.dot(x.dot(w)) * 2 / len(x)

def df_debug(w, x, epsilon = 0.01):
    res = np.empty(len(w))
    for i in range(len(w)):
        w_1 = w.copy()
        w_1[i] += epsilon 
        w_2 = w.copy()
        w_2[i] -= epsilon 
        res[i] = (f(w_1,x) - f(w_2,x)) / (2 * epsilon)
    return res

def direction(w):
    return w / np.linalg.norm(w)

def gradient_ascent(df, x, initial_w, eta, n_iters = 1e4, epsilon = 1e-8):
    w = direction(initial_w)
    cur_iter = 0
    
    while cur_iter < n_iters:
        gradient = df(w,x)
        last_w = w
        w = w + eta * gradient
        w = direction(w)
        if(abs(f(w,x) - f(last_w,x)) < epsilon):
            break
        cur_iter += 1
    return w

# %%
initial_w = np.random.random(x.shape[1])
initial_w
# Out:
# array([0.30580351, 0.54432644])

# %%
eta = 0.001

# %%
gradient_ascent(df_debug,x_demean,initial_w,eta)
# Out:
# array([0.77098018, 0.63685914])

# %%
w = gradient_ascent(df_math,x_demean,initial_w,eta)
w
# Out:
# array([0.77098018, 0.63685914])

# %%
plt.scatter(x_demean[:,0],x_demean[:,1])
plt.plot([0,w[0] * 30],[0,w[1] * 30],color='r')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 求第二主成分

# %%
#先去掉第一个主成分
x2 = x - x.dot(w).reshape(-1,1) * w
x2
# Out:
# array([[ -4.85169168,   5.87344653],
#        [  1.45951613,  -1.76688679],
#        [ -6.09032504,   7.37293316],
#        [ -7.09299123,   8.58675849],
#        [  3.09961983,  -3.75239247],
#        [ 10.16463911, -12.30528819],
#        [  2.67583914,  -3.23936456],
#        [  6.12585196,  -7.41594197],
#        [ -6.24162629,   7.5560981 ],
#        [ -4.11318738,   4.97941496],
#        [ -0.96193567,   1.16451706],
#        [  1.65477252,  -2.00326372],
#        [  5.00443844,  -6.05836139],
#        [  3.80132455,  -4.60187455],
#        [  2.70344474,  -3.27278384],
#        [ -2.22110216,   2.68886105],
#        [ -1.79522778,   2.17329853],
#        [ -4.1685366 ,   5.0464206 ],
#        [ -1.05820048,   1.28105501],
#        [-10.84653987,  13.13079565],
#        [  4.79707128,  -5.80732321],
#        [ -5.01278076,   6.06846059],
#        [  0.1489404 ,  -0.1803069 ],
#        [ -2.951672  ,   3.57328717],
#        [  2.27878159,  -2.75868763],
#        [  3.84858379,  -4.65908648],
#        [  7.27130848,  -8.80262893],
#        [  4.13158362,  -5.0016854 ],
#        [  4.84219378,  -5.8619484 ],
#        [  4.87891589,  -5.90640409],
#        [ -1.58232589,   1.91555999],
#        [  3.69894885,  -4.47793877],
#        [ -1.43156931,   1.73305444],
#        [ -1.5355865 ,   1.8589774 ],
#        [ -4.43525315,   5.36930703],
#        [  5.25396956,  -6.36044319],
#        [-11.99794472,  14.52468364],
#        [ -0.35648311,   0.43155762],
#        [  7.64247627,  -9.25196379],
#        [ -9.81470763,  11.88166196],
#        [  2.00605472,  -2.42852513],
#        [ -7.57947802,   9.17569825],
#        [ -0.33785849,   0.4090107 ],
#        [  2.16695898,  -2.62331544],
#        [ -0.84186618,   1.01916122],
#        [  2.81862039,  -3.41221521],
#        [  5.18881258,  -6.2815643 ],
#        [ -1.75608477,   2.12591209],
#        [ -3.17189767,   3.83989185],
#        [  3.41011366,  -4.12827557],
#        [ -6.86113508,   8.30607398],
#        [ -8.8369391 ,  10.69797768],
#        [ -5.67938585,   6.87545114],
#        [  0.32800231,  -0.39707882],
#        [ -1.52820619,   1.85004282],
#        [ -4.99876002,   6.05148712],
#        [  0.23795004,  -0.28806176],
#        [ -2.15944988,   2.61422494],
#        [  2.01175531,  -2.43542625],
#        [ -0.53213791,   0.6442049 ],
#        [  2.824593  ,  -3.41944563],
#        [ -5.35012006,   6.47684275],
#        [ -1.30370931,   1.57826742],
#        [ -4.3580712 ,   5.27587074],
#        [  6.40058631,  -7.74853472],
#        [  2.27371647,  -2.7525558 ],
#        [ -4.57401051,   5.53728636],
#        [ -5.30783122,   6.42564798],
#        [  6.17597724,  -7.47662352],
#        [  0.39630002,  -0.47975987],
#        [  3.89044509,  -4.70976368],
#        [  1.7933564 ,  -2.17103303],
#        [  9.16840903, -11.0992544 ],
#        [  4.34662332,  -5.26201196],
#        [  8.3600974 , -10.12071424],
#        [  7.63169267,  -9.23890919],
#        [ -0.38372226,   0.46453326],
#        [ 11.24982811, -13.61901543],
#        [  0.37803977,  -0.45765406],
#        [ -6.55945053,   7.94085538],
#        [  3.74929868,  -4.53889216],
#        [  0.65397427,  -0.79169972],
#        [  1.61805415,  -1.95881255],
#        [ -2.483106  ,   3.00604228],
#        [ -0.17332215,   0.20982339],
#        [  0.70425492,  -0.85256935],
#        [ -4.74450042,   5.74368105],
#        [ -1.02801214,   1.24450908],
#        [ -2.07140397,   2.50763677],
#        [ 11.00911377, -13.32760722],
#        [  4.22267459,  -5.11195992],
#        [  8.28614091, -10.03118269],
#        [  1.71961689,  -2.08176416],
#        [ -3.36487141,   4.07350541],
#        [ -5.96974057,   7.22695388],
#        [ -1.50133414,   1.81751157],
#        [  4.72763502,  -5.72326384],
#        [ -2.87145329,   3.47617459],
#        [  1.48094832,  -1.79283255],
#        [ -4.00764648,   4.8516474 ]])

# %%
plt.scatter(x2[:,0],x2[:,1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
w2 = gradient_ascent(df_math,x2,initial_w,eta)
w
